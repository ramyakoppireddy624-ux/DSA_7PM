# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path='visadataset.csv'
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# ## **prevailing_wage**

# %% [markdown]
# - len
#
# - max
#
# - min
#
# - mean
#
# - median
#
# - 25 perecentile
#
# - 50 percentile
#
# - 75 p

# %%
wage_data=visa_df['prevailing_wage']
len(wage_data)
# Out:
# 25480

# %%
min(wage_data)
# Out:
# 2.1367

# %%
wage_data.min()
# Out:
# 2.1367

# %%
np.min(wage_data)
# Out:
# 2.1367

# %%
wage_data=visa_df['prevailing_wage']
min(wage_data),wage_data.min(),np.min(wage_data)
# Out:
# (2.1367, 2.1367, 2.1367)

# %%
wage_data=visa_df['prevailing_wage']
max(wage_data),wage_data.max(),np.max(wage_data)
# Out:
# (319210.27, 319210.27, 319210.27)

# %%
wage_data.mean(),np.mean(wage_data)
# Out:
# (np.float64(74455.81459209183), np.float64(74455.81459209183))

# %%
wage_data.median(),np.median(wage_data)
# Out:
# (70308.20999999999, np.float64(70308.20999999999))

# %% [markdown]
# ## quantile-percentile

# %%
p_25=np.percentile(wage_data,25)
print(p_25)
# Out:
# 34015.479999999996

# %%
p_50=np.percentile(wage_data,50)
print(p_50)
# Out:
# 70308.20999999999

# %%
p_75=np.percentile(wage_data,75)
print(p_75)
# Out:
# 107735.51250000001

# %%
q_25=np.quantile(wage_data,0.25) 
q_25=np.quantile(wage_data,0.50) 
q_25=np.quantile(wage_data,0.75)

# %%
np.quantile(wage_data,0.25)
# Out:
# np.float64(34015.479999999996)

# %%
wage_data=visa_df['prevailing_wage']
wage_count=len(wage_data)
wage_min=round(wage_data.min(),2)
wage_median=round(wage_data.median(),2)
wage_mean=round(wage_data.mean(),2)
wage_25=round(np.percentile(wage_data,25))
wage_50=round(np.percentile(wage_data,50))
wage_75=round(np.percentile(wage_data,75))
wage_max=round(wage_data.max(),2)
l=[wage_count,wage_min,wage_median,wage_mean,wage_25,wage_50,wage_75,wage_max]
ID=['count','min','median','mean','25p','50p','75p','max']
pd.DataFrame(l,columns=['prevailing_wage'],index=ID)
# Out:
#         prevailing_wage
# count          25480.00
# min                2.14
# median         70308.21
# mean           74455.81
# 25p            34015.00
# 50p            70308.00
# 75p           107736.00
# max           319210.27

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
L=[]
for i in num:
    data=visa_df[i]
    count=len(data)
    Min=round(data.min(),2)
    median=round(data.median(),2)
    mean=round(data.mean(),2)
    p_25=round(np.percentile(wage_data,25))
    p_50=round(np.percentile(wage_data,50))
    p_75=round(np.percentile(wage_data,75))
    Max=round(wage_data.max(),2)
    l=[wage_count,wage_min,wage_median,wage_mean,wage_25,wage_50,wage_75,wage_max]
    ID=['count','min','median','mean','25p','50p','75p','max']
    L.append(l) 
pd.DataFrame(L,columns=ID,index=num).T
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00         25480.00
# min                2.14         2.14             2.14
# median         70308.21     70308.21         70308.21
# mean           74455.81     74455.81         74455.81
# 25p            34015.00     34015.00         34015.00
# 50p            70308.00     70308.00         70308.00
# 75p           107736.00    107736.00        107736.00
# max           319210.27    319210.27        319210.27

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# ## **perecentile**

# %% [markdown]
# - 25p:25 percentage of data below 25p value
#
# - wage_25p:34015.48
#
#    - there are 25*(254800)/100=6370 percentile data below 34015.48
#
# - wage_50p:70308
#
#     -there are 50*(254800)/100= 127400 perecentile dsata below 70308
#
# - wage_75:107736
#
#     - there are 75*(107736)/100= 191100 percentile data below 107736

# %%
con=visa_df['prevailing_wage']<wage_25
len(visa_df[con]),len(visa_df)*25/100
# Out:
# (6370, 6370.0)

# %%
len(visa_df[con])==len(visa_df)*25/100
# Out:
# True

# %%
con=visa_df['prevailing_wage']<wage_50
len(visa_df[con]),len(visa_df)*50/100
# Out:
# (12740, 12740.0)

# %%
con=visa_df['prevailing_wage']<wage_75
len(visa_df[con]),len(visa_df)*75/100
# Out:
# (19110, 19110.0)

# %%
u=wage_data.mean()
sigma=wage_data.std()
LB=u-1*sigma
UB=u+1*sigma
con1=visa_df['prevailing_wage']>LB
con2=visa_df['prevailing_wage']<UB
con=con1&con2
len(visa_df[con])==68*25000/100
# Out:
# False

# %% [markdown]
# ## **conclusion**:Emperical rule failed wage data does not following normal distribution

# %% [markdown]
# # histogram

# %%
plt.hist(wage_data,bins=40)
# Out:
# (array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#         1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#          509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#           79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#            7.,    3.,    6.,    5.]),
#  array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#         3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#         6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#         9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#         1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#         1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#         1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#         2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#         2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
# ...

# %%
plt.hist(wage_data,bins=10)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
inter_count,inter_vals,n=plt.hist(wage_data,bins=10)

# %%
inter_count
# Out:
# array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#          21.])

# %%
inter_vals
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %%
lb=2.13670000e+00
ub=3.19229500e+04
con1=visa_df['prevailing_wage']>=lb
con2=visa_df['prevailing_wage']<ub
con=con1&con2
l=len(visa_df[con])
l
# Out:
# 6038

# %%
con=visa_df['prevailing_wage']
con
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
l=[]
for i in num:
    data=visa_df[i]
    count=len(data)
    Min=round(data.min(),2)
    median=round(data.median(),2)
    mean=round(data.mean(),2)
    p_25=round(np.percentile(wage_data,25))
    p_50=round(np.percentile(wage_data,50))
    p_75=round(np.percentile(wage_data,75))
    Max=round(wage_data.max(),2)
    l=[wage_count,wage_min,wage_median,wage_mean,wage_25,wage_50,wage_75,wage_max]
    ID=['count','min','median','mean','25p','50p','75p','max']
    L.append(l)
    pd.DataFrame(L,columns=ID)

# %%
con=visa_df['prevailing_wage']
con
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
data=visa_df['prevailing_wage']
intervals=[(592.20,46623.7),(46623.73,92655.26),(92655.26,138686.79),(138686.79,184718.32),(184718.32,230749.85),(230749.85,276781.38)]
class_intervals=[f"{low}-{high}" for low, high in intervals]
frequencies=[sum(low<=x<=high for x in data)for low,high in intervals]
table=pd.DataFrame(list(zip(class_intervals, frequencies)),columns=["Class Interval", "Frequency"])
print(table)
# Out:
#         Class Interval  Frequency
# 0        592.2-46623.7       6887
# 1    46623.73-92655.26       8224
# 2   92655.26-138686.79       6148
# 3  138686.79-184718.32       1783
# 4  184718.32-230749.85        519
# 5  230749.85-276781.38        268

# %% [markdown]
# ## Outlier Analysis

# %% [markdown]
# - we understood imperical rule failed
#
# - Then we plotted histogram its slightly deviated
#
# - it indicates the data has outliers
#
# - outliers can be show by **box plot**
#
#
#   Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                        |-----:-----|
#        o      |--------|     :     |--------|    o  o
#                        |-----:-----|
#      flier             <----------->            fliers
#                             IQR

# %% [markdown]
# ## **BOXPLOT**

# %%
wage_data=visa_df['prevailing_wage']
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1).hist(wage_data)
plt.subplot(1,2,2).boxplot(wage_data,vert=False)
plt.show()

# %%
wage_data
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
q1=np.quantile(wage_data,0.25)
q2=np.quantile(wage_data,0.50)
q3=np.quantile(wage_data,0.75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q3-1.5*IQR
con1=wage_data>UB
con2=wage_data<LB
con= con1|con2
outlier_df=visa_df[con]
len(outlier_df)
# Out:
# 427

# %%
q1=np.quantile(wage_data,0.25)
q2=np.quantile(wage_data,0.50)
q3=np.quantile(wage_data,0.75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q3-1.5*IQR
con1=wage_data<UB
con2=wage_data>LB
con= con1&con2
non_outlier=visa_df[con]
len(non_outlier)
# Out:
# 25053

# %%
25053+427==25480
# Out:
# True

# %% [markdown]
# ## **Fill the outliers**:
# - drop the outliers
#
# - fill with median
#
# - winsorization:fill with LB and UB

# %%
# we wiil iterate each value from wage_data
# if the value matches :

# %%
outlier_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
outlier_df['prevailing_wage']
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
outliers= outlier_df['prevailing_wage'].values.tolist()
l=[]
wage_data=visa_df['prevailing_wage']
wage_med=wage_data.median()
for value in wage_data:
    if value in outliers:
        l.append(wage_med)
    else:
        l.append(value)
visa_df['prevailing_wage1']=l
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
outliers
# Out:
# [220081.73,
#  225569.73,
#  247393.01,
#  269321.68,
#  219529.62,
#  232227.33,
#  238691.32,
#  220448.17,
#  230750.48,
#  235339.91,
#  232680.65,
#  256261.78,
#  262189.0,
#  250510.67,
#  218554.78,
#  256205.38,
#  221944.22,
#  229950.7,
#  222628.84,
#  229819.69,
#  233641.72,
#  274019.43,
#  218982.83,
#  230984.28,
#  223128.23,
#  246705.0,
#  240266.34,
#  226090.72,
#  231949.27,
#  254604.08,
#  288318.91,
#  244457.48,
#  242146.48,
#  247545.23,
#  234139.17,
#  231834.72,
#  222730.57,
#  239773.63,
#  220553.95,
#  237539.32,
#  266440.49,
#  277281.01,
#  275627.59,
#  249291.12,
#  292106.59,
#  234012.11,
#  247009.24,
#  267726.09,
#  222098.09,
#  280661.13,
#  277984.52,
#  262852.71,
#  263877.21,
#  230916.64,
#  264760.64,
#  267868.56,
#  222221.67,
#  242406.32,
#  276894.08,
#  281832.93,
#  221033.57,
#  258292.84,
#  223492.85,
#  245418.67,
#  250289.08,
#  271344.69,
#  252825.11,
#  230843.7,
#  253668.86,
#  245819.17,
#  239465.3,
# ...

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1).hist(visa_df['prevailing_wage1'])
plt.subplot(1,2,2).boxplot(visa_df['prevailing_wage1'],vert=False)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage1'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage1'],vert=False)
plt.subplot(2,2,3).hist(wage_data)
plt.subplot(2,2,4).boxplot(wage_data,vert=False)
plt.show()

# %%
wage_data=visa_df['prevailing_wage']
q1=np.quantile(wage_data,0.25)
q2=np.quantile(wage_data,0.50)
q3=np.quantile(wage_data,0.75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q3-1.5*IQR
visa_df['prevailing_wage2']=wage_data.clip(lower=LB,upper=UB)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
outliers= outlier_df['prevailing_wage'].values.tolist()
l=[]
wage_data=visa_df['prevailing_wage']
wage_med=wage_data.median()
for value in wage_data:
    if value in outliers:
        l.append(wage_med)
    else:
        l.append(value)
visa_df['prevailing_wage1']=l
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path='visadataset.csv'
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...
